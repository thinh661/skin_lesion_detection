# %%
from flask import Flask, render_template, render_template_string, request
import cv2
import numpy as np
import pandas as pd
import urllib.request
import os
import keras
import tensorflow
import keras.utils as image
from werkzeug.utils import secure_filename
from werkzeug.datastructures import  FileStorage
from keras.utils import load_img,  img_to_array

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from keras import backend as K
from keras.layers import Layer,InputSpec
import keras.layers as kl
from glob import glob
from sklearn.metrics import roc_curve, auc
from keras.preprocessing import image
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score
from tensorflow.keras import callbacks 
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from  matplotlib import pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras.layers import concatenate,Dense, Conv2D, MaxPooling2D, Flatten,Input,Activation,add,AveragePooling2D,BatchNormalization,Dropout
# %matplotlib inline
from tensorflow.python.platform import build_info as tf_build_info
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
#Soft Attention

from keras import backend as K
from keras.layers import Layer,InputSpec
import keras.layers as kl
import tensorflow as tf



class SoftAttention(Layer):
    def __init__(self,ch,m,concat_with_x=False,aggregate=False,**kwargs):
        self.channels=int(ch)
        self.multiheads = m
        self.aggregate_channels = aggregate
        self.concat_input_with_scaled = concat_with_x

        
        super(SoftAttention,self).__init__(**kwargs)

    def build(self,input_shape):

        self.i_shape = input_shape

        kernel_shape_conv3d = (self.channels, 3, 3) + (1, self.multiheads) # DHWC
    
        self.out_attention_maps_shape = input_shape[0:1]+(self.multiheads,)+input_shape[1:-1]
        
        if self.aggregate_channels==False:

            self.out_features_shape = input_shape[:-1]+(input_shape[-1]+(input_shape[-1]*self.multiheads),)
        else:
            if self.concat_input_with_scaled:
                self.out_features_shape = input_shape[:-1]+(input_shape[-1]*2,)
            else:
                self.out_features_shape = input_shape
        

        self.kernel_conv3d = self.add_weight(shape=kernel_shape_conv3d,
                                        initializer='he_uniform',
                                        name='kernel_conv3d')
        self.bias_conv3d = self.add_weight(shape=(self.multiheads,),
                                      initializer='zeros',
                                      name='bias_conv3d')

        super(SoftAttention, self).build(input_shape)

    def call(self, x):

        exp_x = K.expand_dims(x,axis=-1)

        c3d = K.conv3d(exp_x,
                     kernel=self.kernel_conv3d,
                     strides=(1,1,self.i_shape[-1]), padding='same', data_format='channels_last')
        conv3d = K.bias_add(c3d,
                        self.bias_conv3d)
        conv3d = kl.Activation('relu')(conv3d)

        conv3d = K.permute_dimensions(conv3d,pattern=(0,4,1,2,3))

        
        conv3d = K.squeeze(conv3d, axis=-1)
        conv3d = K.reshape(conv3d,shape=(-1, self.multiheads ,self.i_shape[1]*self.i_shape[2]))

        softmax_alpha = K.softmax(conv3d, axis=-1) 
        softmax_alpha = kl.Reshape(target_shape=(self.multiheads, self.i_shape[1],self.i_shape[2]))(softmax_alpha)

        
        if self.aggregate_channels==False:
            exp_softmax_alpha = K.expand_dims(softmax_alpha, axis=-1)       
            exp_softmax_alpha = K.permute_dimensions(exp_softmax_alpha,pattern=(0,2,3,1,4))
   
            x_exp = K.expand_dims(x,axis=-2)
   
            u = kl.Multiply()([exp_softmax_alpha, x_exp])   
  
            u = kl.Reshape(target_shape=(self.i_shape[1],self.i_shape[2],u.shape[-1]*u.shape[-2]))(u)

        else:
            exp_softmax_alpha = K.permute_dimensions(softmax_alpha,pattern=(0,2,3,1))

            exp_softmax_alpha = K.sum(exp_softmax_alpha,axis=-1)

            exp_softmax_alpha = K.expand_dims(exp_softmax_alpha, axis=-1)

            u = kl.Multiply()([exp_softmax_alpha, x])   

        if self.concat_input_with_scaled:
            o = kl.Concatenate(axis=-1)([u,x])
        else:
            o = u
        
        return [o, softmax_alpha]

    def compute_output_shape(self, input_shape): 
        return [self.out_features_shape, self.out_attention_maps_shape]

    
    def get_config(self):
        return super(SoftAttention,self).get_config()

# %%
irv2 = tf.keras.applications.InceptionResNetV2(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classifier_activation="softmax",

)

# Excluding the last 28 layers of the model.
conv = irv2.layers[-28].output

# %%
attention_layer,map2 = SoftAttention(aggregate=True,m=16,concat_with_x=False,ch=int(conv.shape[-1]),name='soft_attention')(conv)
attention_layer=(MaxPooling2D(pool_size=(2, 2),padding="same")(attention_layer))
conv=(MaxPooling2D(pool_size=(2, 2),padding="same")(conv))

conv = concatenate([conv,attention_layer])
conv  = Activation('relu')(conv)
conv = Dropout(0.5)(conv)

# %%
output = Flatten()(conv)
output = Dense(7, activation='softmax')(output)
model = Model(inputs=irv2.input, outputs=output)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_406 (Conv2D)         (None, 149, 149, 32)         864       ['input_3[0][0]']
#
#  batch_normalization_406 (B  (None, 149, 149, 32)         96        ['conv2d_406[0][0]']
#  atchNormalization)
#
#  activation_407 (Activation  (None, 149, 149, 32)         0         ['batch_normalization_406[0][0
#  )                                                                  ]']
#
#  conv2d_407 (Conv2D)         (None, 147, 147, 32)         9216      ['activation_407[0][0]']
#
#  batch_normalization_407 (B  (None, 147, 147, 32)         96        ['conv2d_407[0][0]']
#  atchNormalization)
#
#  activation_408 (Activation  (None, 147, 147, 32)         0         ['batch_normalization_407[0][0
#  )                                                                  ]']
#
#  conv2d_408 (Conv2D)         (None, 147, 147, 64)         18432     ['activation_408[0][0]']
#
#  batch_normalization_408 (B  (None, 147, 147, 64)         192       ['conv2d_408[0][0]']
#  atchNormalization)
#
#  activation_409 (Activation  (None, 147, 147, 64)         0         ['batch_normalization_408[0][0
#  )                                                                  ]']
#
#  max_pooling2d_10 (MaxPooli  (None, 73, 73, 64)           0         ['activation_409[0][0]']
#  ng2D)
#
#  conv2d_409 (Conv2D)         (None, 73, 73, 80)           5120      ['max_pooling2d_10[0][0]']
#
#  batch_normalization_409 (B  (None, 73, 73, 80)           240       ['conv2d_409[0][0]']
#  atchNormalization)
#
#  activation_410 (Activation  (None, 73, 73, 80)           0         ['batch_normalization_409[0][0
#  )                                                                  ]']
#
#  conv2d_410 (Conv2D)         (None, 71, 71, 192)          138240    ['activation_410[0][0]']
#
#  batch_normalization_410 (B  (None, 71, 71, 192)          576       ['conv2d_410[0][0]']
#  atchNormalization)
#
#  activation_411 (Activation  (None, 71, 71, 192)          0         ['batch_normalization_410[0][0
#  )                                                                  ]']
#
#  max_pooling2d_11 (MaxPooli  (None, 35, 35, 192)          0         ['activation_411[0][0]']
#  ng2D)
#
#  conv2d_414 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_11[0][0]']
#
#  batch_normalization_414 (B  (None, 35, 35, 64)           192       ['conv2d_414[0][0]']
#  atchNormalization)
#
#  activation_415 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_414[0][0
#  )                                                                  ]']
#
#  conv2d_412 (Conv2D)         (None, 35, 35, 48)           9216      ['max_pooling2d_11[0][0]']
#
#  conv2d_415 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_415[0][0]']
#
#  batch_normalization_412 (B  (None, 35, 35, 48)           144       ['conv2d_412[0][0]']
#  atchNormalization)
#
#  batch_normalization_415 (B  (None, 35, 35, 96)           288       ['conv2d_415[0][0]']
#  atchNormalization)
#
#  activation_413 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_412[0][0
#  )                                                                  ]']
#
#  activation_416 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_415[0][0
#  )                                                                  ]']
#
#  average_pooling2d_2 (Avera  (None, 35, 35, 192)          0         ['max_pooling2d_11[0][0]']
#  gePooling2D)
#
#  conv2d_411 (Conv2D)         (None, 35, 35, 96)           18432     ['max_pooling2d_11[0][0]']
#
#  conv2d_413 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_413[0][0]']
#
#  conv2d_416 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_416[0][0]']
#
#  conv2d_417 (Conv2D)         (None, 35, 35, 64)           12288     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_411 (B  (None, 35, 35, 96)           288       ['conv2d_411[0][0]']
#  atchNormalization)
#
#  batch_normalization_413 (B  (None, 35, 35, 64)           192       ['conv2d_413[0][0]']
#  atchNormalization)
#
#  batch_normalization_416 (B  (None, 35, 35, 96)           288       ['conv2d_416[0][0]']
#  atchNormalization)
#
#  batch_normalization_417 (B  (None, 35, 35, 64)           192       ['conv2d_417[0][0]']
#  atchNormalization)
#
#  activation_412 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_411[0][0
#  )                                                                  ]']
#
#  activation_414 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_413[0][0
#  )                                                                  ]']
#
#  activation_417 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_416[0][0
#  )                                                                  ]']
#
#  activation_418 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_417[0][0
#  )                                                                  ]']
#
#  mixed_5b (Concatenate)      (None, 35, 35, 320)          0         ['activation_412[0][0]',
#                                                                      'activation_414[0][0]',
#                                                                      'activation_417[0][0]',
#                                                                      'activation_418[0][0]']
#
#  conv2d_421 (Conv2D)         (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_421 (B  (None, 35, 35, 32)           96        ['conv2d_421[0][0]']
#  atchNormalization)
#
#  activation_422 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_421[0][0
#  )                                                                  ]']
#
#  conv2d_419 (Conv2D)         (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_422 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_422[0][0]']
#
#  batch_normalization_419 (B  (None, 35, 35, 32)           96        ['conv2d_419[0][0]']
#  atchNormalization)
#
#  batch_normalization_422 (B  (None, 35, 35, 48)           144       ['conv2d_422[0][0]']
#  atchNormalization)
#
#  activation_420 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_419[0][0
#  )                                                                  ]']
#
#  activation_423 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_422[0][0
#  )                                                                  ]']
#
#  conv2d_418 (Conv2D)         (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_420 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_420[0][0]']
#
#  conv2d_423 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_423[0][0]']
#
#  batch_normalization_418 (B  (None, 35, 35, 32)           96        ['conv2d_418[0][0]']
#  atchNormalization)
#
#  batch_normalization_420 (B  (None, 35, 35, 32)           96        ['conv2d_420[0][0]']
#  atchNormalization)
#
#  batch_normalization_423 (B  (None, 35, 35, 64)           192       ['conv2d_423[0][0]']
#  atchNormalization)
#
#  activation_419 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_418[0][0
#  )                                                                  ]']
#
#  activation_421 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_420[0][0
#  )                                                                  ]']
#
#  activation_424 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_423[0][0
#  )                                                                  ]']
#
#  block35_1_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_419[0][0]',
#  te)                                                                 'activation_421[0][0]',
#                                                                      'activation_424[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer_80 (Cus  (None, 35, 35, 320)          0         ['mixed_5b[0][0]',
#  tomScaleLayer)                                                      'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_80[0][0]'
#                                                                     ]
#
#  conv2d_427 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_427 (B  (None, 35, 35, 32)           96        ['conv2d_427[0][0]']
#  atchNormalization)
#
#  activation_428 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_427[0][0
#  )                                                                  ]']
#
#  conv2d_425 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_428 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_428[0][0]']
#
#  batch_normalization_425 (B  (None, 35, 35, 32)           96        ['conv2d_425[0][0]']
#  atchNormalization)
#
#  batch_normalization_428 (B  (None, 35, 35, 48)           144       ['conv2d_428[0][0]']
#  atchNormalization)
#
#  activation_426 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_425[0][0
#  )                                                                  ]']
#
#  activation_429 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_428[0][0
#  )                                                                  ]']
#
#  conv2d_424 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_426 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_426[0][0]']
#
#  conv2d_429 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_429[0][0]']
#
#  batch_normalization_424 (B  (None, 35, 35, 32)           96        ['conv2d_424[0][0]']
#  atchNormalization)
#
#  batch_normalization_426 (B  (None, 35, 35, 32)           96        ['conv2d_426[0][0]']
#  atchNormalization)
#
#  batch_normalization_429 (B  (None, 35, 35, 64)           192       ['conv2d_429[0][0]']
#  atchNormalization)
#
#  activation_425 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_424[0][0
#  )                                                                  ]']
#
#  activation_427 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_426[0][0
#  )                                                                  ]']
#
#  activation_430 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_429[0][0
#  )                                                                  ]']
#
#  block35_2_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_425[0][0]',
#  te)                                                                 'activation_427[0][0]',
#                                                                      'activation_430[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_81 (Cus  (None, 35, 35, 320)          0         ['block35_1_ac[0][0]',
#  tomScaleLayer)                                                      'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_81[0][0]'
#                                                                     ]
#
#  conv2d_433 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_433 (B  (None, 35, 35, 32)           96        ['conv2d_433[0][0]']
#  atchNormalization)
#
#  activation_434 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_433[0][0
#  )                                                                  ]']
#
#  conv2d_431 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_434 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_434[0][0]']
#
#  batch_normalization_431 (B  (None, 35, 35, 32)           96        ['conv2d_431[0][0]']
#  atchNormalization)
#
#  batch_normalization_434 (B  (None, 35, 35, 48)           144       ['conv2d_434[0][0]']
#  atchNormalization)
#
#  activation_432 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_431[0][0
#  )                                                                  ]']
#
#  activation_435 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_434[0][0
#  )                                                                  ]']
#
#  conv2d_430 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_432 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_432[0][0]']
#
#  conv2d_435 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_435[0][0]']
#
#  batch_normalization_430 (B  (None, 35, 35, 32)           96        ['conv2d_430[0][0]']
#  atchNormalization)
#
#  batch_normalization_432 (B  (None, 35, 35, 32)           96        ['conv2d_432[0][0]']
#  atchNormalization)
#
#  batch_normalization_435 (B  (None, 35, 35, 64)           192       ['conv2d_435[0][0]']
#  atchNormalization)
#
#  activation_431 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_430[0][0
#  )                                                                  ]']
#
#  activation_433 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_432[0][0
#  )                                                                  ]']
#
#  activation_436 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_435[0][0
#  )                                                                  ]']
#
#  block35_3_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_431[0][0]',
#  te)                                                                 'activation_433[0][0]',
#                                                                      'activation_436[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_82 (Cus  (None, 35, 35, 320)          0         ['block35_2_ac[0][0]',
#  tomScaleLayer)                                                      'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_82[0][0]'
#                                                                     ]
#
#  conv2d_439 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_439 (B  (None, 35, 35, 32)           96        ['conv2d_439[0][0]']
#  atchNormalization)
#
#  activation_440 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_439[0][0
#  )                                                                  ]']
#
#  conv2d_437 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_440 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_440[0][0]']
#
#  batch_normalization_437 (B  (None, 35, 35, 32)           96        ['conv2d_437[0][0]']
#  atchNormalization)
#
#  batch_normalization_440 (B  (None, 35, 35, 48)           144       ['conv2d_440[0][0]']
#  atchNormalization)
#
#  activation_438 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_437[0][0
#  )                                                                  ]']
#
#  activation_441 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_440[0][0
#  )                                                                  ]']
#
#  conv2d_436 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_438 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_438[0][0]']
#
#  conv2d_441 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_441[0][0]']
#
#  batch_normalization_436 (B  (None, 35, 35, 32)           96        ['conv2d_436[0][0]']
#  atchNormalization)
#
#  batch_normalization_438 (B  (None, 35, 35, 32)           96        ['conv2d_438[0][0]']
#  atchNormalization)
#
#  batch_normalization_441 (B  (None, 35, 35, 64)           192       ['conv2d_441[0][0]']
#  atchNormalization)
#
#  activation_437 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_436[0][0
#  )                                                                  ]']
#
#  activation_439 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_438[0][0
#  )                                                                  ]']
#
#  activation_442 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_441[0][0
#  )                                                                  ]']
#
#  block35_4_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_437[0][0]',
#  te)                                                                 'activation_439[0][0]',
#                                                                      'activation_442[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_83 (Cus  (None, 35, 35, 320)          0         ['block35_3_ac[0][0]',
#  tomScaleLayer)                                                      'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_83[0][0]'
#                                                                     ]
#
#  conv2d_445 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_445 (B  (None, 35, 35, 32)           96        ['conv2d_445[0][0]']
#  atchNormalization)
#
#  activation_446 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_445[0][0
#  )                                                                  ]']
#
#  conv2d_443 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_446 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_446[0][0]']
#
#  batch_normalization_443 (B  (None, 35, 35, 32)           96        ['conv2d_443[0][0]']
#  atchNormalization)
#
#  batch_normalization_446 (B  (None, 35, 35, 48)           144       ['conv2d_446[0][0]']
#  atchNormalization)
#
#  activation_444 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_443[0][0
#  )                                                                  ]']
#
#  activation_447 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_446[0][0
#  )                                                                  ]']
#
#  conv2d_442 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_444 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_444[0][0]']
#
#  conv2d_447 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_447[0][0]']
#
#  batch_normalization_442 (B  (None, 35, 35, 32)           96        ['conv2d_442[0][0]']
#  atchNormalization)
#
#  batch_normalization_444 (B  (None, 35, 35, 32)           96        ['conv2d_444[0][0]']
#  atchNormalization)
#
#  batch_normalization_447 (B  (None, 35, 35, 64)           192       ['conv2d_447[0][0]']
#  atchNormalization)
#
#  activation_443 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_442[0][0
#  )                                                                  ]']
#
#  activation_445 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_444[0][0
#  )                                                                  ]']
#
#  activation_448 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_447[0][0
#  )                                                                  ]']
#
#  block35_5_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_443[0][0]',
#  te)                                                                 'activation_445[0][0]',
#                                                                      'activation_448[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_84 (Cus  (None, 35, 35, 320)          0         ['block35_4_ac[0][0]',
#  tomScaleLayer)                                                      'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_84[0][0]'
#                                                                     ]
#
#  conv2d_451 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_451 (B  (None, 35, 35, 32)           96        ['conv2d_451[0][0]']
#  atchNormalization)
#
#  activation_452 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_451[0][0
#  )                                                                  ]']
#
#  conv2d_449 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_452 (Conv2D)         (None, 35, 35, 48)           13824     ['activation_452[0][0]']
#
#  batch_normalization_449 (B  (None, 35, 35, 32)           96        ['conv2d_449[0][0]']
#  atchNormalization)
#
#  batch_normalization_452 (B  (None, 35, 35, 48)           144       ['conv2d_452[0][0]']
#  atchNormalization)
#
#  activation_450 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_449[0][0
#  )                                                                  ]']
#
#  activation_453 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_452[0][0
#  )                                                                  ]']
#
#  conv2d_448 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_450 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_450[0][0]']
#
#  conv2d_453 (Conv2D)         (None, 35, 35, 64)           27648     ['activation_453[0][0]']
#
#  batch_normalization_448 (B  (None, 35, 35, 32)           96        ['conv2d_448[0][0]']
#  atchNormalization)
#
#  batch_normalization_450 (B  (None, 35, 35, 32)           96        ['conv2d_450[0][0]']
#  atchNormalization)
#
#  batch_normalization_453 (B  (None, 35, 35, 64)           192       ['conv2d_453[0][0]']
#  atchNormalization)
#
#  activation_449 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_448[0][0
#  )                                                                  ]']
#
#  activation_451 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_450[0][0
#  )                                                                  ]']
#
#  activation_454 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_453[0][0
#  )                                                                  ]']
#
#  block35_6_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_449[0][0]',
#  te)                                                                 'activation_451[0][0]',
#                                                                      'activation_454[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_85 (Cus  (None, 35, 35, 320)          0         ['block35_5_ac[0][0]',
#  tomScaleLayer)                                                      'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_85[0][0]'
#                                                                     ]
#
#  conv2d_457 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_457 (B  (None, 35, 35, 32)           96        ['conv2d_457[0][0]']
#  atchNormalization)
#
#  activation_458 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_457[0][0
#  )                                                                  ]']
#
#  conv2d_455 (Conv2D)         (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
# ...
#  block8_5_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_114[0][0]
#                                                                     ']
#
#  conv2d_590 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_5_ac[0][0]']
#
#  batch_normalization_590 (B  (None, 8, 8, 192)            576       ['conv2d_590[0][0]']
#  atchNormalization)
#
#  activation_591 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_590[0][0
#  )                                                                  ]']
#
#  conv2d_591 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_591[0][0]']
#
#  batch_normalization_591 (B  (None, 8, 8, 224)            672       ['conv2d_591[0][0]']
#  atchNormalization)
#
#  activation_592 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_591[0][0
#  )                                                                  ]']
#
#  conv2d_589 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_5_ac[0][0]']
#
#  conv2d_592 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_592[0][0]']
#
#  batch_normalization_589 (B  (None, 8, 8, 192)            576       ['conv2d_589[0][0]']
#  atchNormalization)
#
#  batch_normalization_592 (B  (None, 8, 8, 256)            768       ['conv2d_592[0][0]']
#  atchNormalization)
#
#  activation_590 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_589[0][0
#  )                                                                  ]']
#
#  activation_593 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_592[0][0
#  )                                                                  ]']
#
#  block8_6_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_590[0][0]',
#  e)                                                                  'activation_593[0][0]']
#
#  block8_6_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_6_mixed[0][0]']
#
#  custom_scale_layer_115 (Cu  (None, 8, 8, 2080)           0         ['block8_5_ac[0][0]',
#  stomScaleLayer)                                                     'block8_6_conv[0][0]']
#
#  block8_6_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_115[0][0]
#                                                                     ']
#
#  conv2d_594 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_6_ac[0][0]']
#
#  batch_normalization_594 (B  (None, 8, 8, 192)            576       ['conv2d_594[0][0]']
#  atchNormalization)
#
#  activation_595 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_594[0][0
#  )                                                                  ]']
#
#  conv2d_595 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_595[0][0]']
#
#  batch_normalization_595 (B  (None, 8, 8, 224)            672       ['conv2d_595[0][0]']
#  atchNormalization)
#
#  activation_596 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_595[0][0
#  )                                                                  ]']
#
#  conv2d_593 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_6_ac[0][0]']
#
#  conv2d_596 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_596[0][0]']
#
#  batch_normalization_593 (B  (None, 8, 8, 192)            576       ['conv2d_593[0][0]']
#  atchNormalization)
#
#  batch_normalization_596 (B  (None, 8, 8, 256)            768       ['conv2d_596[0][0]']
#  atchNormalization)
#
#  activation_594 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_593[0][0
#  )                                                                  ]']
#
#  activation_597 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_596[0][0
#  )                                                                  ]']
#
#  block8_7_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_594[0][0]',
#  e)                                                                  'activation_597[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_116 (Cu  (None, 8, 8, 2080)           0         ['block8_6_ac[0][0]',
#  stomScaleLayer)                                                     'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_116[0][0]
#                                                                     ']
#
#  conv2d_598 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_598 (B  (None, 8, 8, 192)            576       ['conv2d_598[0][0]']
#  atchNormalization)
#
#  activation_599 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_598[0][0
#  )                                                                  ]']
#
#  conv2d_599 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_599[0][0]']
#
#  batch_normalization_599 (B  (None, 8, 8, 224)            672       ['conv2d_599[0][0]']
#  atchNormalization)
#
#  activation_600 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_599[0][0
#  )                                                                  ]']
#
#  conv2d_597 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_600 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_600[0][0]']
#
#  batch_normalization_597 (B  (None, 8, 8, 192)            576       ['conv2d_597[0][0]']
#  atchNormalization)
#
#  batch_normalization_600 (B  (None, 8, 8, 256)            768       ['conv2d_600[0][0]']
#  atchNormalization)
#
#  activation_598 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_597[0][0
#  )                                                                  ]']
#
#  activation_601 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_600[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_598[0][0]',
#  e)                                                                  'activation_601[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_117 (Cu  (None, 8, 8, 2080)           0         ['block8_7_ac[0][0]',
#  stomScaleLayer)                                                     'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_117[0][0]
#                                                                     ']
#
#  conv2d_601 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_601 (B  (None, 8, 8, 192)            576       ['conv2d_601[0][0]']
#  atchNormalization)
#
#  soft_attention (SoftAttent  [(None, 8, 8, 192),          27664     ['batch_normalization_601[0][0
#  ion)                         (None, 16, 8, 8)]                     ]']
#
#  max_pooling2d_15 (MaxPooli  (None, 4, 4, 192)            0         ['batch_normalization_601[0][0
#  ng2D)                                                              ]']
#
#  max_pooling2d_14 (MaxPooli  (None, 4, 4, 192)            0         ['soft_attention[0][0]']
#  ng2D)
#
#  concatenate_1 (Concatenate  (None, 4, 4, 384)            0         ['max_pooling2d_15[0][0]',
#  )                                                                   'max_pooling2d_14[0][0]']
#
#  activation_610 (Activation  (None, 4, 4, 384)            0         ['concatenate_1[0][0]']
#  )
#
#  dropout_1 (Dropout)         (None, 4, 4, 384)            0         ['activation_610[0][0]']
#
#  flatten_1 (Flatten)         (None, 6144)                 0         ['dropout_1[0][0]']
#
#  dense_1 (Dense)             (None, 7)                    43015     ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 47535287 (181.33 MB)
# Trainable params: 47480887 (181.13 MB)
# Non-trainable params: 54400 (212.50 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import models
model.load_weights(r"D:\WorkSpace_Thinh1\Nhom15-Parallel-Source\ReactJSParallel\server1\IRV2+SA.hdf5")

# %%
Image = image.load_img(r"D:\WorkSpace_Thinh1\Nhom15-Parallel-Source\ReactJSParallel\server1\data_test\ISIC2018_Task3_Test_Images\ISIC_0036023.jpg", target_size = (299, 299))
Image_array_ = np.asarray(Image)
Image_array_ = image.img_to_array(Image)
Image_array_numpy = (Image_array_/255)
test_data = np.expand_dims(Image_array_numpy, axis = 0)
predicted_ =  model.predict(test_data)
print(predicted_[0][3])

predicted_class = np.argmax(predicted_, axis=1)
predicted_probability = np.max(predicted_, axis=1)
print(f'Predicted class: {predicted_class[0]} with probability: {predicted_probability[0] * 100:.2f}%')
print(predicted_probability,predicted_class)

predicted_ = np.argmax(predicted_, axis = 1)

print(predicted_)
# Out:
# 1/1 [==============================] - 0s 423ms/step
# 0.001070587
# Predicted class: 2 with probability: 86.55%
# [0.8654814] [2]
# [2]
